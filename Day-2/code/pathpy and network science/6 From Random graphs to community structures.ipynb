# %% [markdown]
# # Random Graph Models
#
# **September 08 2020**
# *Vincenzo Perri*
#
# Random graphs are models of networks in which we fix some aggregated characteristic and allow everything else to vary.
# This entails that a random graph does not define a single network but rather a probability distribution over possible networks, also referred to as an `ensamble`of networks.
# Ensambles define what is expected at random for networks with the aforementioned fixed aggregated characteristic. This 'expectation' is particularly useful as, by comparison, it tells us what is unexpected and thus interesting.
#
# Pathpy provides build-generators for random graph models. In this notebook we study the properties of the generated networks and compare them to those of empirical networks.

# %%
import pathpy as pp
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('default')
sns.set_style("whitegrid")
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>

# %% [markdown]
# ## The $G(n,m)$ model by Pál Erdös and Alred Rényi
#
# The $G(n,m)$ models model generates the ensamble of graphs with $n$ nodes and $m$ edges.

# %% [markdown]
# A number of random graph models (among them $G(n,m)$ and $G(n,p)$) are implemented in the `pathpy` module `generators`. To generate random graphs using the $G(n,m)$ model we can write:

# %%
# pp.generators.ER_nm(30, 40, directed=False)

# %% [markdown]
# We can also generate networks directed or undirected with or without loops and with multiple edges.

# %% [markdown]
# Note that there is a limit to the number of (non multi-) edges that can be put in a graph. If you want to quickly check the maximum number of possible edges for such networks with a given number of nodes, you can use the `max_edges` functions.

# %%
print(pp.generators.max_edges(100, directed=True, loops=True))
print(pp.generators.max_edges(100, directed=True, loops=False))
print(pp.generators.max_edges(100, directed=False, loops=True))
print(pp.generators.max_edges(100, directed=False, loops=False))
# Out:
# 10000
# 9900
# 5050
# 4950

# %% [markdown]
# In any case, if we specify parameters of an impossible network, the function issues the appropriate error message:

# %%
pp.generators.ER_nm(n=100, m=5060, directed=False, loops=True)
# Out:
# [09-07 15:19:55: ERROR] Given network type with n nodes can have at most 5050 edges.

# %% [markdown]
# ## The $G(n,p)$ model by Edgar Nelson Gilbert
#
# A downside of the $G(n,m)$ model is that links are not generated independely. We can address this with another model originally proposed by Edgar Nelson Gilbert. It assumes that we initially generate n isolated nodes, then connecting each pair of nodes with a fixed probability p (i.e. through a Bernoulli trial):

# %% [markdown]
# We can use the function `pp.generators.ER_np` to generate networks according to the $G(n,p)$ model:

# %%
pp.generators.ER_np(n=100, p=0.02)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x565e09c91bf4423bb4f25d87776e000f"></div>
# <div id="x95a960a4c4cf410490ca1ddd58e0c0d7"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "0", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "1", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "2", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "4", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "5", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "6", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "7", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "8", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "9", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "10", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "11", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "12", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "13", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "14", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "15", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "16", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "17", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "18", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "19", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "20", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "21", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "22", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "23", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "24", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "25", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "26", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "27", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "28", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "29", "size": 15.0, "color": "Cornflow

# %% [markdown]
# ## Randomizing networks

# %% [markdown]
# We often use random graph models to randomize the topology of a given network, while keeping their aggregate characteristics.
#
# To simplify the generation of random microstates that preserve the macrostate of an empirical network, the functions in the module `pathpy.generators` come in a `randomize` version, which automatically preserve the corresponding macrostate of a given network. In the case of the $G(n,p)$ model this automatically adjust the parameters $n$ and $p$ such that the expected number of links matches the observed number of links in the given network.. To see how this works, consider the following example network:

# %%
n_undirected = pp.Network(directed=False)
n_undirected.add_edge('a', 'b')
n_undirected.add_edge('b', 'c')
n_undirected.add_edge('c', 'a')
n_undirected.add_edge('d', 'e')
n_undirected.add_edge('e', 'f')
n_undirected.add_edge('f', 'g')
n_undirected.add_edge('g', 'd')
n_undirected.add_edge('d', 'f')
n_undirected.add_edge('b', 'd')
n_undirected.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x317dd4940fc445edafcd1077f2bc5834"></div>
# <div id="x9f450db8175941bb8213f2d5e6f78c6d"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "e", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "f", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "g", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1c305047c10", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": false, "curved": 0.5}, {"uid": "0x1c305047ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": false, "curved": 0.5}, {"uid": "0x1c3050440a0", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "a", "directed": false, "curved": 0.5}, {"uid": "0x1c3050441c0", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "e", "directed": false, "curved": 0.5}, {"uid": "0x1c305044400", "size": 2.0, "color": "black", "opacity": 1, "source": "e", "target": "f", "directed": false, "curved": 0.5}, {"uid": "0x1c3050445b0", "size": 2.0, "color": "black", "opacity": 1, "source": "f", "target": "g", "directed": false, "curved": 0.5}, {"uid": "0x1c305044760", "size": 2.0, "color": "black", "opacity": 1, "source": "g", "target": "d", "directed": false, "curved": 0.5}, {"uid": "0x1c305044880", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "f", "directed": false, "curved": 0.5}, {"uid": "0x1c3050449a0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "d", "directed": false, "curved": 0.5}]}
#
#    function tooltip(tooltipId, width){
#      // Local variable to hold tooltip div for
#      // manipulation in other functions.
#      var tt = d3.select('body')
#                 .append('div')
#                 .attr('class', 'tooltip')
#                 .attr('id', tooltipId)
#                 .style('pointer-events', 'none');
#
#      // Set a width if it is provided.
#      if (width) {
#        tt.style('width', width);
#      }
#
#      // Initially it is hidden.
#      hideTooltip();
#
#      /*
#       * Display tooltip with provided content.
#       * content is expected to be HTML string.
#       * event is d3.event for positioning.
#       */
#      function showTooltip(content, event) {
#        tt.style('opacity', 1.0)
#          .html(content);
#
#        updatePosition(event);
#      }
#
#      /*
#       * Hide the tooltip div.
#       */
#      function hideTooltip() {
#        tt.style('

# %% [markdown]
# We can use the $G(n,m)$ model to generate a random version of this network with the same number of nodes, edges, the same edge directedness and the same node uids as follows

# %%
pp.generators.ER_nm_randomize(n_undirected)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xfb3fc2c841264f45ac436ec8c0680129"></div>
# <div id="x07dc4fa471f1461abcc34b9a842dee23"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "e", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "f", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "g", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1c305047700", "size": 2.0, "color": "black", "opacity": 1, "source": "g", "target": "c", "directed": false, "curved": 0.5}, {"uid": "0x1c305047910", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "f", "directed": false, "curved": 0.5}, {"uid": "0x1c305047af0", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "a", "directed": false, "curved": 0.5}, {"uid": "0x1c304fd29d0", "size": 2.0, "color": "black", "opacity": 1, "source": "f", "target": "e", "directed": false, "curved": 0.5}, {"uid": "0x1c305026e80", "size": 2.0, "color": "black", "opacity": 1, "source": "f", "target": "d", "directed": false, "curved": 0.5}, {"uid": "0x1c3733e6910", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "a", "directed": false, "curved": 0.5}, {"uid": "0x1c304f51d30", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "g", "directed": false, "curved": 0.5}, {"uid": "0x1c304f51dc0", "size": 2.0, "color": "black", "opacity": 1, "source": "f", "target": "g", "directed": false, "curved": 0.5}, {"uid": "0x1c305044bb0", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "b", "directed": false, "curved": 0.5}]}
#
#    function tooltip(tooltipId, width){
#      // Local variable to hold tooltip div for
#      // manipulation in other functions.
#      var tt = d3.select('body')
#                 .append('div')
#                 .attr('class', 'tooltip')
#                 .attr('id', tooltipId)
#                 .style('pointer-events', 'none');
#
#      // Set a width if it is provided.
#      if (width) {
#        tt.style('width', width);
#      }
#
#      // Initially it is hidden.
#      hideTooltip();
#
#      /*
#       * Display tooltip with provided content.
#       * content is expected to be HTML string.
#       * event is d3.event for positioning.
#       */
#      function showTooltip(content, event) {
#        tt.style('opacity', 1.0)
#          .html(content);
#
#        updatePosition(event);
#      }
#
#      /*
#       * Hide the tooltip div.
#       */
#      function hideTooltip() {
#        tt.style('

# %% [markdown]
# We can do the swme for the $G(n,p)$ model. Here the parameter $p$ is automatically fitted to the given network, i.e. it is chosen such that the number of *expected links* in the generated microstates matches the number of links in the given network:

# %%
pp.generators.ER_np_randomize(n_undirected)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xff3e1f1759b24a35903bc32c0cfded09"></div>
# <div id="xec37ca9121ec4af7902306e225b55f75"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "e", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "f", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "g", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1c30505b520", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "f", "directed": false, "curved": 0.5}, {"uid": "0x1c30505b640", "size": 2.0, "color": "black", "opacity": 1, "source": "g", "target": "a", "directed": false, "curved": 0.5}, {"uid": "0x1c30505b760", "size": 2.0, "color": "black", "opacity": 1, "source": "g", "target": "e", "directed": false, "curved": 0.5}, {"uid": "0x1c30505b880", "size": 2.0, "color": "black", "opacity": 1, "source": "g", "target": "f", "directed": false, "curved": 0.5}, {"uid": "0x1c30505b9a0", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "b", "directed": false, "curved": 0.5}, {"uid": "0x1c30505bac0", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "g", "directed": false, "curved": 0.5}, {"uid": "0x1c30505bbe0", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "a", "directed": false, "curved": 0.5}, {"uid": "0x1c30505bd00", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "e", "directed": false, "curved": 0.5}, {"uid": "0x1c30505be20", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "b", "directed": false, "curved": 0.5}, {"uid": "0x1c30505bf40", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "g", "directed": false, "curved": 0.5}, {"uid": "0x1c3060330a0", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "d", "directed": false, "curved": 0.5}]}
#
#    function tooltip(tooltipId, width){
#      // Local variable to hold tooltip div for
#      // manipulation in other functions.
#      var tt = d3.select('body')
#                 .append('div')
#                 .attr('class', 'tooltip')
#                 .attr('id', tooltipId)
#                 .style('pointer-events', 'none');
#
#      // Set a width if it is provided.
#      if (width) {
#        tt.style('width', width);
#      }
#
#      // Initially it is hidden.
#      hideTooltip();
#
#      /*
#       * Display tooltip with provided content.
#       * content is expected to be HTML string.
#       * event is

# %% [markdown]
# ## Degree distribution of random $G(n,m)$ vs. empirical networks
#
#
# Let us now study the degree distribution of random graphs, comparing them to the degree distributions of empirical networks. For this, we first load three empirical networks:

# %%
n_gentoo = pp.io.sql.read_network('networks.db', sql='SELECT source, target FROM gentoo', directed=False)
n_highschool = pp.io.sql.read_network('networks.db', sql='SELECT source, target FROM highschool', directed=False, multiedges = True )
n_lotr = pp.io.sql.read_network('networks.db', sql='SELECT source, target FROM "lotr"', directed=False, multiedges = False).largest_connected_component()
# Out:
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gollum,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gollum,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gollum,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Meriadoc,Peregrin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sméagol,Déagol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sméagol,Déagol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sméagol,Déagol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Isildur,Elendil) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gollum,Déagol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gollum,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Bilbo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Bilbo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Fredegar) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Merry,Fredegar) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Merry,Fredegar) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Lobelia,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Maggot,Pippin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Peregrin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Maggot,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Maggot,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Maggot,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Maggot,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Butterbur,Barliman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Butterbur,Barliman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Nob,Butterbur) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Butterbur) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Nob,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Merry,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Bob,Bill) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Nob,Butterbur) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Merry,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Nob,Bob) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Elendil,Gil-galad) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Merry,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Beren,Lúthien) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Beren,Barahir) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Beren,Thingol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Beren,Lúthien) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Beren,Thingol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Lúthien,Thingol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Beren,Thingol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Beren,Lúthien) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Thingol,Lúthien) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Glorfindel,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Glorfindel,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Glorfindel,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Glorfindel,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Glorfindel,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Glorfindel,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Glorfindel,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Lúthien) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Glóin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Glóin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Arwen,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Arwen,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:56: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# ...
# [09-07 15:19:57: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Bill) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Merry,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Lotho) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Lotho) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Lotho) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Meriadoc,Peregrin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Merry,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Merry,Saruman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Gandalf,Saruman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Saruman,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Saruman,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Saruman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Saruman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Saruman,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Saruman,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Fredegar) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Lotho) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Meriadoc,Peregrin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Peregrin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Bill) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Elrond,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Elrond,Galadriel) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Galadriel) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Elrond,Galadriel) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Galadriel,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Sam,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Galadriel) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Merry,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Galadriel,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-07 15:19:57: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!

# %% [markdown]
# For each network, we first plot the empirical degree distribution.

# %% [markdown]
# We then use the `ER_nm_randomize` function to generate a random microstate where the model parameters of the underlying $G(n,m)$ model have been adjusted to the number of nodes and links in the empirical network:

# %%
er_gentoo = pp.generators.random_graphs.ER_nm_randomize(n_gentoo)
er_highschool = pp.generators.random_graphs.ER_nm_randomize(n_highschool)
er_lotr = pp.generators.random_graphs.ER_nm_randomize(n_lotr)

# %% [markdown]
# **gentoo**

# %%
sns.distplot(n_gentoo.degree_sequence(), label="empirical");
sns.distplot(er_gentoo.degree_sequence(), label = "random");
plt.legend()

# %% [markdown]
# **highschool**

# %%
sns.distplot(n_highschool.degree_sequence(), label="empirical");
sns.distplot(er_highschool.degree_sequence(), label = "random");
plt.legend()

# %% [markdown]
# **lotr**

# %%
sns.distplot(n_lotr.degree_sequence(), label="empirical");
sns.distplot(er_lotr.degree_sequence(), label = "random");
plt.legend()

# %% [markdown]
# In particular for this last network, we find that the degree distribution of the random network is much more narrow than that of the empirical network. In other words: Compared to a simple random graph model this broad degree distribution actually constitutes an interesting pattern that we seek to model and explain.

# %% [markdown]
# ## Configuration Model
#
# Above we investigated ensambles generated fixing properties such as the number of edges or the average degree.
# As we saw above the degree distributions of random networks grossly differ from that of the real networks.
# We may want to generalize random graph models so that the fixed property is the degree distribution.
# This is exactly what the Molloy-Reed model -also called configuration model- does, providing a way to generate random graphs with any *graphic* degree sequence.

# %% [markdown]
# In sentence above we highlighted the "graphic" because not every sequence is compatible with being the degree sequence of a graph.
# In pathpy we can test whether a sequence is graphic (i.e. whether a graph exists that has the sequence as degree sequence) with the `is_graphic_Erdos_Gallai` function in the `generators`module:

# %%
graphic_sequence = [1,2,2,3]
pp.generators.is_graphic_Erdos_Gallai(graphic_sequence)
# Out:
# True

# %%
non_graphic_sequence = [2,2,2,3]
pp.generators.is_graphic_Erdos_Gallai(non_graphic_sequence)
# Out:
# False

# %% [markdown]
# Graphic sequences are relevant since with them we can implement the Molloy-Reed/Configuration model, which generates random networks with an arbitrary degree distribution. This model is implemented by the following function:

# %%
pp.generators.Molloy_Reed(graphic_sequence)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x016393025bde42b58840b19aec7d1906"></div>
# <div id="xafff6316ddfe40be94b9631150434622"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "0", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "1", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "2", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "3", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1c309096670", "size": 2.0, "color": "black", "opacity": 1, "source": "3", "target": "2", "directed": false, "curved": 0.5}, {"uid": "0x1c309096ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "1", "target": "2", "directed": false, "curved": 0.5}, {"uid": "0x1c309096640", "size": 2.0, "color": "black", "opacity": 1, "source": "3", "target": "0", "directed": false, "curved": 0.5}, {"uid": "0x1c309096910", "size": 2.0, "color": "black", "opacity": 1, "source": "1", "target": "3", "directed": false, "curved": 0.5}]}
#
#    function tooltip(tooltipId, width){
#      // Local variable to hold tooltip div for
#      // manipulation in other functions.
#      var tt = d3.select('body')
#                 .append('div')
#                 .attr('class', 'tooltip')
#                 .attr('id', tooltipId)
#                 .style('pointer-events', 'none');
#
#      // Set a width if it is provided.
#      if (width) {
#        tt.style('width', width);
#      }
#
#      // Initially it is hidden.
#      hideTooltip();
#
#      /*
#       * Display tooltip with provided content.
#       * content is expected to be HTML string.
#       * event is d3.event for positioning.
#       */
#      function showTooltip(content, event) {
#        tt.style('opacity', 1.0)
#          .html(content);
#
#        updatePosition(event);
#      }
#
#      /*
#       * Hide the tooltip div.
#       */
#      function hideTooltip() {
#        tt.style('opacity', 0.0);
#      }
#
#      /*
#       * Figure out where to place the tooltip
#       * based on d3 mouse event.
#       */
#      function updatePosition(event) {
#        var xOffset = 20;
#        var yOffset = 10;
#
#        var ttw = tt.style('width');
#        var tth = tt.style('height');
#
#        var wscrY = window.scrollY;
#        var wscrX = window.scrollX;
#
#        var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#        var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#        var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                     curX - ttw - xOffset * 2 : curX + xOffset;
#
#        if (ttleft < wscrX + xOffset) {
#          ttleft = wscrX + xOffset;
#        }
#
#        var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                    curY - tth - yOffset * 2 : curY + yOffset;
#
#        if (tttop < wscrY + yOffset) {
#          tttop = curY + yOffset;
#        }

# %% [markdown]
# if we try to pass sequence that is not graphic (do we get an error message?):

# %%
pp.generators.Molloy_Reed(non_graphic_sequence)

# %% [markdown]
# We can look at the degree sequences generated from the Molloy-Reed model and confirm that they are identical to those of the empirical networks.
#
# For the Molloy-Reed model, the `_randomize` method fixes the degree sequence of the empirical network in the generation of a random microstate. All other network properties like, e.g. node uids are preserved.

# %%
mr_gentoo = pp.generators.random_graphs.Molloy_Reed_randomize(n_gentoo)
mr_highschool = pp.generators.random_graphs.Molloy_Reed_randomize(n_highschool)

# %%
mr_lotr =  pp.generators.random_graphs.Molloy_Reed_randomize(n_lotr)

# %%
sns.distplot(n_gentoo.degree_sequence(), label="empirical");
sns.distplot(mr_gentoo.degree_sequence(), label = "random");
plt.legend()

# %%
sns.distplot(n_highschool.degree_sequence(), label="empirical");
sns.distplot(mr_highschool.degree_sequence(), label = "random");
plt.legend()

# %%
sns.distplot(n_lotr.degree_sequence(), label="empirical");
sns.distplot(mr_lotr.degree_sequence(), label = "random");
plt.legend()

# %% [markdown]
# we can also generate networks with a fixed degree distribution rather than a fixed degree sequence. For this we first draw degree sequences from a given distribution, check whether the sequence is graphic and then apply the model above. Below, we apply this to a sequence of 300 degrees drawn from a *Zipf* distribution with parameter $\gamma=2.7$.

# %%
degrees_zipf = [1]
while not pp.generators.is_graphic_Erdos_Gallai(degrees_zipf):
    degrees_zipf = [int(x) for x in np.random.zipf(2.5, 300)]

g_zipf = pp.generators.Molloy_Reed(degrees_zipf)
# g_zipf.plot()

# %%
sns.distplot(pp.statistics.degree_sequence(g_zipf));

# %% [markdown]
# # Diameter and clustering coefficient of random networks vs. empirical networks
#
# An important application of the Molloy-Reed model in statistical network analysis is as a null model that helps us to establish a baseline for what we can expect at random, if we account for the heterogeneous degrees in a real network. To show the advantage over simple rrandom graph models that only preserve the size of the network, we make an experiment with real data. We compare the diameter and average shortest path length of the largest connected component in empirical networks with those of random microstates generated using the $G(n,p)$ and the Molloy-Reed model.
#
# Before performing the comparison we must the connectedness of the networks.

# %%
print("\nemp")
print(n_gentoo.is_connected)
print(n_highschool.is_connected)
print(n_lotr.is_connected)

print("\nG(n,m)")
print(er_gentoo.is_connected)
print(er_highschool.is_connected)
print(er_lotr.is_connected)

print("\nmolloy reed")
print(mr_gentoo.is_connected)
print(mr_highschool.is_connected)
print(mr_lotr.is_connected)
# Out:
# emp
# True
# True
# True
#
# G(n,m)
# False
# True
# False
#
# molloy reed
# False
# True
# False

# %% [markdown]
# For gentoo the random realization is not connected, which would lead to an infinite diameter and average shortest path length. To still allow for an approximate comparison, we can compute the calculations on the largest connected component.

# %%
er_gentoo = pp.generators.random_graphs.ER_np_randomize(er_gentoo).largest_connected_component()
mr_gentoo = pp.generators.random_graphs.ER_np_randomize(n_gentoo).largest_connected_component()
print("Empirical network has", n_gentoo.number_of_nodes(), "nodes and", n_gentoo.number_of_edges(), "edges")
print("G(n,p) microstate has", er_gentoo.number_of_nodes(), "nodes and", er_gentoo.number_of_edges(), "edges")
print("Molloy-Reed microstate has", mr_gentoo.number_of_nodes(), "nodes and", mr_gentoo.number_of_edges(), "edges")
# Out:
# Empirical network has 403 nodes and 513 edges
# G(n,p) microstate has 363 nodes and 502 edges
# Molloy-Reed microstate has 362 nodes and 476 edges

# %%
#GENTOO
# Empirical 
diameter_n_gentoo = n_gentoo.largest_connected_component().diameter()
avg_pl_n_gentoo = pp.algorithms.avg_path_length(n_gentoo)
avg_clst_n_gentoo = n_gentoo.avg_clustering_coefficient()
# G(n,p)
diameter_er_gentoo = er_gentoo.diameter()
avg_pl_er_gentoo = pp.algorithms.avg_path_length(er_gentoo)
avg_clst_er_gentoo = er_gentoo.avg_clustering_coefficient()
# Molloy-Reed
diameter_mr_gentoo = mr_gentoo.diameter()
avg_pl_mr_gentoo = pp.algorithms.avg_path_length(mr_gentoo)
avg_clst_mr_gentoo = mr_gentoo.avg_clustering_coefficient()
print("\ngentoo\n----------")
print("empirical")
print('Diameter = ', diameter_n_gentoo)
print('Avg path length = ', avg_pl_n_gentoo)
print('Clustering coefficient = ', avg_clst_n_gentoo)
print("----------")
print("$G(n,m)")
print('Diameter = ', diameter_er_gentoo)
print('Avg path length = ', avg_pl_er_gentoo)
print('Clustering coefficient = ', avg_clst_er_gentoo)
print("----------")
print("Molloy-Reed")
print('Diameter = ', diameter_mr_gentoo)
print('Avg path length = ', avg_pl_mr_gentoo)
print('Clustering coefficient = ', avg_clst_mr_gentoo)
# Out:
# gentoo
# ----------
# empirical
# Diameter =  8.0
# Avg path length =  3.1096379146451367
# Clustering coefficient =  0.017357355654577633
# ----------
# $G(n,m)
# Diameter =  14.0
# Avg path length =  6.2781912545850265
# Clustering coefficient =  0.006268310813765359
# ----------
# Molloy-Reed
# Diameter =  14.0
# Avg path length =  6.550833320579728
# Clustering coefficient =  0.008379373848987109

# %% [markdown]
# For **gentoo** we find that the diameter and the average shortest path length of the largest connected component of the random realizations are larger than that of the empirical network. Both the randomized and the empirical networks have low clustering coefficient.

# %%
# HIGHSCHOOL
# Empirical 
diameter_n_highschool = n_highschool.diameter()
avg_pl_n_highschool = pp.algorithms.avg_path_length(n_highschool)
avg_clst_n_highschool = n_highschool.avg_clustering_coefficient()
# G(n,p)
diameter_er_highschool = er_highschool.diameter()
avg_pl_er_highschool = pp.algorithms.avg_path_length(er_highschool)
avg_clst_er_highschool = er_highschool.avg_clustering_coefficient()
# Molloy-Reed
diameter_mr_highschool = mr_highschool.diameter()
avg_pl_mr_highschool = pp.algorithms.avg_path_length(mr_highschool)
avg_clst_mr_highschool = mr_highschool.avg_clustering_coefficient()
print("\nhighschool\n----------")
print("empirical")
print('Diameter = ', diameter_n_highschool)
print('Avg path length = ', avg_pl_n_highschool)
print('Clustering coefficient = ', avg_clst_n_highschool)
print("----------")
print("$G(n,m)")
print('Diameter = ', diameter_er_highschool)
print('Avg path length = ', avg_pl_er_highschool)
print('Clustering coefficient = ', avg_clst_er_highschool)
print("----------")
print("Molloy-Reed")
print('Diameter = ', diameter_mr_highschool)
print('Avg path length = ', avg_pl_mr_highschool)
print('Clustering coefficient = ', avg_clst_mr_highschool)
# Out:
# highschool
# ----------
# empirical
# Diameter =  12.0
# Avg path length =  5.362745098039215
# Clustering coefficient =  0.3269545310354134
# ----------
# $G(n,m)
# Diameter =  4.0
# Avg path length =  2.4756302521008404
# Clustering coefficient =  0.06701201576201576
# ----------
# Molloy-Reed
# Diameter =  5.0
# Avg path length =  2.4784313725490197
# Clustering coefficient =  0.08402153810242045

# %% [markdown]
# For **highschool** the diameter and average path lengths of the random realization are smaller than that of the empirical network, i.e. we find the opposite case compared to the gentoo network. The clustering coefficient of the empirical network is much higher than that of the randomized ones.

# %%
# LOTR
# Empirical 
diameter_n_lotr = n_lotr.diameter()
avg_pl_n_lotr = pp.algorithms.avg_path_length(n_lotr)
avg_clst_n_lotr = n_lotr.avg_clustering_coefficient()
# G(n,p)
diameter_er_lotr = er_lotr.diameter()
avg_pl_er_lotr = pp.algorithms.avg_path_length(er_lotr)
avg_clst_er_lotr = er_lotr.avg_clustering_coefficient()
# Molloy-Reed
diameter_mr_lotr = mr_lotr.diameter()
avg_pl_mr_lotr = pp.algorithms.avg_path_length(mr_lotr)
avg_clst_mr_lotr = mr_lotr.avg_clustering_coefficient()
print("\nlotr\n----------")
print("empirical")
print('Diameter = ', diameter_n_lotr)
print('Avg path length = ', avg_pl_n_lotr)
print('Clustering coefficient = ', avg_clst_n_lotr)
print("----------")
print("$G(n,m)")
print('Diameter = ', diameter_er_lotr)
print('Avg path length = ', avg_pl_er_lotr)
print('Clustering coefficient = ', avg_clst_er_lotr)
print("----------")
print("Molloy-Reed")
print('Diameter = ', diameter_mr_lotr)
print('Avg path length = ', avg_pl_mr_lotr)
print('Clustering coefficient = ', avg_clst_mr_lotr)
# Out:
# lotr
# ----------
# empirical
# Diameter =  6.0
# Avg path length =  2.6724273369992146
# Clustering coefficient =  0.5848854454659764
# ----------
# $G(n,m)
# Diameter =  inf
# Avg path length =  inf
# Clustering coefficient =  0.08552530213959905
# ----------
# Molloy-Reed
# Diameter =  inf
# Avg path length =  inf
# Clustering coefficient =  0.2447901300325477

# %% [markdown]
# For **lotr** we observe that the diameter of the $G(n,m)$ is slightly smaller than that of the empirical network. The diameter of the Molloy-Reed microstate instead is in line with that of the empirical network.
# Interestingly in this case we see that part of the high value of clustering observed in the empirical network is explained by the degree sequence.

# %% [markdown]
# ## Modularity-based Community Detection
#
# We conclude this notebook with an application of modularity-based community detection to empirical networks.
# The partition quality function $Q(n, C)$ that captures how well a given mapping of nodes to communities is aligned with the topology of a network. This function can be used to develop a simple community detection algorithm that is based on the heuristic optimisation of partition quality.
#
# The partition quality $Q(G, C)$ is defined as
# $$ Q(G,C) = \frac{1}{2m} \sum_{i,j \in V}\left(A_{ij} - \frac{d_id_j}{2m}\right) \delta(c_i,c_j) $$ where $d_i$ denotes the degree of node $i$
#
# In a nutshell it compares the connections actually present between nodes in the same community ($A_{ij}$) with *expected* number of connections between those nodes ($\frac{d_id_j}{2m}$).
# If that *expected* caught your attention, you are on the right track as this expectation is once again based on the Molloy-Reed model!

# %%
n = pp.Network(directed=False)
n.add_edge('a', 'b')
n.add_edge('b', 'c')
n.add_edge('a', 'c')
n.add_edge('b', 'd')
n.add_edge('d', 'f')
n.add_edge('d', 'g')
n.add_edge('d', 'e')
n.add_edge('e', 'f')
n.add_edge('f', 'g')
# n.plot()

# %%
C, q = pp.algorithms.community_detection.modularity_maximisation(n, iterations=100)
print('Community partition =', C)
print('Modularity =', q)
# Out:
# Community partition = {'a': 0, 'e': 5, 'f': 5, 'b': 5, 'g': 5, 'd': 5, 'c': 0}
# Modularity = 0.12345679012345682

# %% [markdown]
# We can also use the function `color_map` to generate a color mapping that can be directly passed to the `plot` function:

# %%
# n.plot(node_color=pp.algorithms.community_detection.color_map(n, C))

# %%
C, q = pp.algorithms.community_detection.modularity_maximisation(n_highschool, iterations=2000)
# Out:
# maximising modularity: 100%|███████████████████████████████████████████████████████| 2000/2000 [03:11<00:00, 10.46it/s]

# %%
# n_highschool.plot(node_color=pp.algorithms.community_detection.color_map(n_highschool, C))
